# %% [markdown]
# # Computer Vision and Image Recognition Prep

# %% [markdown]
# **[Computer Vision: Crash Course Computer Science #35](https://www.youtube.com/watch?v=-4E2-0sxVUM)** (11:09)
#
# We return to another one of Carrie Anne's crash courses to explore the topic of computer vision. This video provides context for how in general computers are taught how to "see" as well as the applications for computer vision.

# %% [markdown]
# **[How we teach computers to understand pictures | Fei Fei Li](https://www.youtube.com/watch?v=40riCqvRoMs)** (18:02)
#
# Fei-Fei Li is quoted from this TED Talk in the previous crash course video. Here, she presents the general progression researchers have made in computer vision and discusses insights she's gained from her work in the field.

# %% [markdown]
# **[Train an Image Classifier with TensorFlow for Poets](https://www.youtube.com/watch?v=cSKfRcEDGUs):** (7:06)
#
# Now that you have some familiarity with machine learning we are going to give you the opportunity to work on your own state of the art image recognition project! Before we get into the projects Josh will walk you through how he implements an image classifier with tensorflow!

# %% [markdown]
# **Reflections:**
# ​
# * Humans naturally think in a way that makes visual information easily interpretable. Computers, on the other hand, do not. What makes it so much more difficult for a computer to understand images?
# ​
# * What issues might arise from undisclosed or generous use of tools like facial recognition or affective computing (reading emotions on people's faces)?

# %% [markdown]
# # MNIST Mini-Project Demo

# %% [markdown]
# **[MNIST Project Description](https://docs.google.com/document/d/1A2X5x7I6pQLZdpWbaTlZHvNHGrWKO194E0hIlviReE0/edit):**
#
# Next we are going to walk you through our own image recognition demo. This will allow you to play and interact with some advanced neural networks with the MNIST dataset. Check out the MINST project description so you are familiar with the project dataset and objectives.

# %% [markdown]
# **[MNIST Mini-Project Demo](https://colab.research.google.com/drive/1iTn-955vrJ9Ezd-p99Ba-niIjwx_Ap10):**
#
# Click on the link above to run the demo.

# %% [markdown]
# # CIFAR-10 Mini-Project

# %% [markdown]
# **[CIFAR-10 Project Description](https://docs.google.com/document/d/19jeyp4aKXM0El3K6rAuLtAwYlCoVnr9kEIzMDqrRX0w/edit):**
#
# Here is your moment of truth. Now that you are familiar with machine learning and deep neural networks it's time for you to play around and create your own unique image recognition system! Before you begin make sure to read the project description document linked above.

# %% [markdown]
# **[CIFAR-10 Project Rubric](https://docs.google.com/document/d/1FKwdoE-N8K9QjEX8iAp4aYAJw2CXjPd-fo5d1eu2S9s/edit):**
#
# Also be sure to thoroughly review the project rubric so you know what is expected. This project will be self-evaluated but please use this document as a reflection tool to make sure you covered all the learning objectives.

# %% [markdown]
# **[CIFAR-10 Mini-Project](https://colab.research.google.com/drive/1KTQQxkj37_2dydQee4uI4j-kEPl1WKOp#scrollTo=7pSot9elfrv9):**
#
# Once you have reviewed the project demo and rubric it is time to work on your own neural network system! Do not hesitate to look at the helpful comments, the previous MINIST project demo or the online documentation listed in the notebook. If you get stuck don't hesitate to reach out to your peers or the staff. These are some pretty advanced techniques that until even just several years ago were unattainable by even world class AI researchers!
#
# If you manage to complete all the assigned task you are more than welcome to implement the network with more layers or even add lower level keras and tensorflow techniques we abstracted away!
#
# Good luck and remember have fun!

# %% [markdown]
# # Extra Resources (Optional)

# %% [markdown]
# Congratulations on completeing the mini-projects and creating your very own image recognition system!
#
# In the MNIST and CIFAR-10 projects you briefly learned about convolutional neural nets even though you were not expected to have a detailed understanding of their inner workings. This optional section is for those who would like to learn more about convolutional neural networks so they can continue working on their projects!

# %% [markdown]
# [A friendly introduction to convolutional neural networks and image recognition](https://www.youtube.com/watch?v=2-Ol7ZB0MmU) (32:07)
#
# While you got some idea of how a convolution neural network works, in this video Luis will walk you in more detail how convolutional networks learn to recognize images with some simple calculations.

# %% [markdown]
# [Convolutional Neural Networks for Visual Recognition](http://cs231n.github.io/convolutional-networks/):
#
# Now that you got a more indepth understanding of how convolutional neural nets learns, take a look at this visual article that expands your understanding of how the calculations are performed and the dimensions calculated.

# %% [markdown]
# [ImageNet Classification with Deep Convolutional
# Neural Networks](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf):
#
# If you now feel extremely confident in your conceptual understanding of convolutional nets, how to calculate their outputs, and program a working implemention feel free to read this research paper to draw inspiration as you further develop your models!

# %% [markdown]
# [Cifar-10-competition-winners-interviews](http://blog.kaggle.com/2015/01/02/cifar-10-competition-winners-interviews-with-dr-ben-graham-phil-culliton-zygmunt-zajac/):
#
# In our mini-projects we had you interfacing with some custom wrappers to abstract away the underlying Keras and Tensorflow function calls. If you are up to the task see if you can take off the training wheels and implement the Keras or Tensorflow layers yourself and see how your model performs against the competition!

# %% [markdown]
# [Dermatologist-level classification of skin cancer with deep neural networks](https://www.nature.com/articles/nature21056.epdf?author_access_token=8oxIcYWf5UNrNpHsUHd2StRgN0jAjWel9jnR3ZoTv0NXpMHRAJy8Qn10ys2O4tuPakXos4UhQAFZ750CsBNMMsISFHIKinKDMKjShCpHIlYPYUHhNzkn6pSnOCt0Ftf6):
#
# Looking for further inspiration how to apply image recognition systems for good? Check out this article how convolutional neural networks are being used to look for skin cancer!
